# %% [markdown]
# # World Model Representation Research
#
# ### Research Update 9/9-9/16
#
# Cedric Liu

# %% [markdown]
# ## Research Question
#
# Under a fixed data and model budget, when does exposing a specific physical factor explicitly improve compact dynamics learning?
